# %%
df = spark.read.format('csv') \
    .option("inferSchema", True) \
    .option("header", True) \
    .load("/Volumes/ecommerce_electroics_sales/sales_schema/electronic_sales/bronze/Updated_sales.csv")

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_clean = df.toDF(*[c.replace(" ","_") for c in df.columns])

# %%
df_clean.write.format("delta").mode('overwrite')\
    .saveAsTable("ecommerce_electroics_sales.sales_schema.bronze_sales")
